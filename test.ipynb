# %%
import pandas as pd
import numpy as np

# %%
np.random.rand(42)
# Out:
# array([0.115022  , 0.76491043, 0.63429371, 0.85086063, 0.25218022,
#        0.86599777, 0.6566509 , 0.76667446, 0.26666124, 0.32917677,
#        0.42871642, 0.46730103, 0.294002  , 0.61784727, 0.99943574,
#        0.88648298, 0.72664897, 0.67028356, 0.44026889, 0.25933166,
#        0.91950684, 0.38140909, 0.16382352, 0.27371355, 0.36185959,
#        0.34846353, 0.85000062, 0.80436001, 0.13271796, 0.33351019,
#        0.29659554, 0.74964896, 0.90211865, 0.39867822, 0.43427354,
#        0.05330513, 0.05422161, 0.38651011, 0.7678287 , 0.95856795,
#        0.2706156 , 0.35353307])
